# %% [markdown]
# <a href="https://colab.research.google.com/github/JhonathanSam/Python/blob/main/Simple_Linear_SalaryvsYearsofExperiance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# simple linear regression machine learning algorithms
#
# takes single column - input - x
#
# single output y - target variable - goal
#
# Regression Target - continous numeric data
#
# relationship between input and output

# %% [markdown]
# Dataset - data - 2columns
#
# input - height
#
# output - weight - result- target
#
# y - dependent variable
#
# x- independent variable

# %% [markdown]
# importing packages

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# Load data

# %%
from google.colab import files
d=files.upload()
# Out:
#      <input type="file" id="files-784f5546-c130-4802-be7f-bc19a38e1afc" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-784f5546-c130-4802-be7f-bc19a38e1afc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df=pd.read_csv('data.csv')
df
# Out:
#     Height  Weight
# 0     1.47   52.21
# 1     1.50   53.12
# 2     1.52   54.48
# 3     1.55   55.84
# 4     1.57   57.20
# 5     1.60   58.57
# 6     1.63   59.93
# 7     1.65   61.29
# 8     1.68   63.11
# 9     1.70   64.47
# 10    1.73   66.28
# 11    1.75   68.10
# 12    1.78   69.92
# 13    1.80   72.19
# 14    1.83   74.46

# %% [markdown]
# Analysis Dataset

# %%
df.shape # number of rows and columns
# Out:
# (15, 2)

# %%
df.size
# Out:
# 30

# %%
df.columns
# Out:
# Index(['Height', 'Weight'], dtype='object')

# %%
df.head()
# Out:
#    Height  Weight
# 0    1.47   52.21
# 1    1.50   53.12
# 2    1.52   54.48
# 3    1.55   55.84
# 4    1.57   57.20

# %%
df.tail()
# Out:
#     Height  Weight
# 10    1.73   66.28
# 11    1.75   68.10
# 12    1.78   69.92
# 13    1.80   72.19
# 14    1.83   74.46

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Height  15 non-null     float64
#  1   Weight  15 non-null     float64
# dtypes: float64(2)
# memory usage: 372.0 bytes

# %%
df.dtypes
# Out:
# Height    float64
# Weight    float64
# dtype: object

# %%
# checking missing data
df.isna().sum()
# Out:
# Height    0
# Weight    0
# dtype: int64

# %%
df.isna().mean()
# Out:
# Height    0.0
# Weight    0.0
# dtype: float64

# %%
df.isnull().sum()
# Out:
# Height    0
# Weight    0
# dtype: int64

# %% [markdown]
# This shows there is no missing data

# %% [markdown]
# Statistical Analysis of data

# %%
df.describe()
# Out:
#           Height     Weight
# count  15.000000  15.000000
# mean    1.650667  62.078000
# std     0.114235   7.037515
# min     1.470000  52.210000
# 25%     1.560000  56.520000
# 50%     1.650000  61.290000
# 75%     1.740000  67.190000
# max     1.830000  74.460000

# %%
df.describe().T
# Out:
#         count       mean       std    min    25%    50%    75%    max
# Height   15.0   1.650667  0.114235   1.47   1.56   1.65   1.74   1.83
# Weight   15.0  62.078000  7.037515  52.21  56.52  61.29  67.19  74.46

# %% [markdown]
# Checking correlation
#
# relationship between columns

# %%
df.corr() # numeric
# Out:
#           Height    Weight
# Height  1.000000  0.994584
# Weight  0.994584  1.000000

# %%
# visualization
sns.heatmap(data=df.corr(),annot=True,fmt='0.2f')
# Out:
# <Axes: >

# %%
sns.relplot(data=df)

# %%
sns.barplot(data=df,x='Height',y='Weight')
# Out:
# <Axes: xlabel='Height', ylabel='Weight'>

# %%
# visualization of complete dataset
plt.scatter(df['Height'],df['Weight'])
plt.title('Height Weight Chart')
plt.xlabel('Height')
plt.ylabel('Weight')
plt.show()

# %% [markdown]
# separate x and y
#
# inputs and outputs

# %%
x=df.iloc[:,0] # all rows, first column
x
# Out:
# 0     1.47
# 1     1.50
# 2     1.52
# 3     1.55
# 4     1.57
# 5     1.60
# 6     1.63
# 7     1.65
# 8     1.68
# 9     1.70
# 10    1.73
# 11    1.75
# 12    1.78
# 13    1.80
# 14    1.83
# Name: Height, dtype: float64

# %%
y=df.iloc[:,-1] # last column
y
# Out:
# 0     52.21
# 1     53.12
# 2     54.48
# 3     55.84
# 4     57.20
# 5     58.57
# 6     59.93
# 7     61.29
# 8     63.11
# 9     64.47
# 10    66.28
# 11    68.10
# 12    69.92
# 13    72.19
# 14    74.46
# Name: Weight, dtype: float64

# %%
x.head()
# Out:
# 0    1.47
# 1    1.50
# 2    1.52
# 3    1.55
# 4    1.57
# Name: Height, dtype: float64

# %%
y.head()
# Out:
# 0    52.21
# 1    53.12
# 2    54.48
# 3    55.84
# 4    57.20
# Name: Weight, dtype: float64

# %% [markdown]
# Train Test Split
#
# Most train, less data test
#
# sklearn package
#
# parado principle - ratio
#
# train data  - test data
#
# 80            20
#
# 90            10
#
# 70            30
#
# 75            25
#
# random state - rare numbers - 0,1,21,42,101,35

# %%
# train test split
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,train_size=0.7,random_state=0)

# %%
# Training data
15 * 0.7
# Out:
# 10.5

# %%
# testing data
15*0.3
# Out:
# 4.5

# %%
xtrain
# Out:
# 4     1.57
# 2     1.52
# 13    1.80
# 10    1.73
# 7     1.65
# 11    1.75
# 3     1.55
# 0     1.47
# 5     1.60
# 12    1.78
# Name: Height, dtype: float64

# %%
xtest
# Out:
# 1     1.50
# 6     1.63
# 8     1.68
# 9     1.70
# 14    1.83
# Name: Height, dtype: float64

# %%
ytrain
# Out:
# 4     57.20
# 2     54.48
# 13    72.19
# 10    66.28
# 7     61.29
# 11    68.10
# 3     55.84
# 0     52.21
# 5     58.57
# 12    69.92
# Name: Weight, dtype: float64

# %%
ytest
# Out:
# 1     53.12
# 6     59.93
# 8     63.11
# 9     64.47
# 14    74.46
# Name: Weight, dtype: float64

# %%
xtrain.shape
# Out:
# (10,)

# %%
ytrain.shape
# Out:
# (10,)

# %%
xtest.shape
# Out:
# (5,)

# %%
ytest.shape
# Out:
# (5,)

# %% [markdown]
# all these data are in single dimensional
#
# some of the algorithms requires data in 2 dimensional

# %% [markdown]
# Model Building
#
# Simple Linear regression SLR

# %%
from sklearn.linear_model import LinearRegression

# %%
linreg=LinearRegression()

# %%
# fit the data into the model
linreg.fit(xtrain,ytrain)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-43-2029517535.py in <cell line: 0>()
#       1 # fit the data into the model
# ----> 2 linreg.fit(xtrain,ytrain)
#
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1387                 )
#    1388             ):
# -> 1389                 return fit_method(estimator, *args, **kwargs)
#    1390
#    1391         return wrapper
#
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_base.py in fit(self, X, y, sample_weight)
#     599         accept_sparse = False if self.positive else ["csr", "csc", "coo"]
#     600
# --> 601         X, y = validate_data(
#     602             self,
#     603             X,
#
# ...

# %% [markdown]
# convert single dimensional data to 2dimension

# %%
xtrain.shape
# Out:
# (10,)

# %%
xtrain
# Out:
# 4     1.57
# 2     1.52
# 13    1.80
# 10    1.73
# 7     1.65
# 11    1.75
# 3     1.55
# 0     1.47
# 5     1.60
# 12    1.78
# Name: Height, dtype: float64

# %%
# 2 dimension
xtrain=xtrain.values.reshape(-1,1) # row unknown
ytrain=ytrain.values.reshape(-1,1)
xtest=xtest.values.reshape(-1,1)
ytest=ytest.values.reshape(-1,1)

# %%
xtrain.shape
# Out:
# (10, 1)

# %%
xtrain
# Out:
# array([[1.57],
#        [1.52],
#        [1.8 ],
#        [1.73],
#        [1.65],
#        [1.75],
#        [1.55],
#        [1.47],
#        [1.6 ],
#        [1.78]])

# %%
xtrain.ndim
# Out:
# 2

# %% [markdown]
# Model Building

# %%
linreg.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
xtest # actual data in dataset
# Out:
# array([[1.5 ],
#        [1.63],
#        [1.68],
#        [1.7 ],
#        [1.83]])

# %%
ytest # result data in dataset
# Out:
# array([[53.12],
#        [59.93],
#        [63.11],
#        [64.47],
#        [74.46]])

# %%
# model Prediction
ypred =linreg.predict(xtest)
ypred # model predicted data
# Out:
# array([[53.1008463 ],
#        [60.8890856 ],
#        [63.88456226],
#        [65.08275292],
#        [72.87099222]])

# %%
# residual error
err=ytest -ypred
err
# Out:
# array([[ 0.0191537 ],
#        [-0.9590856 ],
#        [-0.77456226],
#        [-0.61275292],
#        [ 1.58900778]])

# %%
# visualization
plt.scatter(xtest,ytest,color='blue') # actual data
plt.plot(xtest,ypred,color='red') # predicted result
plt.title('Height Weight Chart')
plt.xlabel('Height')
plt.ylabel('Weight')
plt.show()

# %% [markdown]
# Evaluation Metrics
#
# performance of the model - ytest,ypred
#
# Regression Algorithms
#
# Mean absolute errors,
#
# Mean squared errors,
#
# Root mean squared errors
#
# r2 score

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,root_mean_squared_error,r2_score

# %%
print(mean_absolute_error(ytest,ypred))
# Out:
# 0.790912451361865

# %%
print(mean_squared_error(ytest,ypred))
# Out:
# 0.8841141236619748

# %%
root_mean_squared_error(ytest,ypred)
# Out:
# 0.9402734302648219

# %%
r2_score(ytest,ypred)
# Out:
# 0.9816224797640154

# %%
df=pd.read_csv('Student_Performance.csv')
df
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0                 7               99                        Yes            9
# 1                 4               82                         No            4
# 2                 8               51                        Yes            7
# 3                 5               52                        Yes            5
# 4                 7               75                         No            8
# ...             ...              ...                        ...          ...
# 9995              1               49                        Yes            4
# 9996              7               64                        Yes            8
# 9997              6               83                        Yes            8
# 9998              9               97                        Yes            7
# 9999              7               74                         No            8
#
# ...

# %%
# Define independent variables (features) and dependent variable (target)
X = df[['Hours Studied', 'Previous Scores']]  # features
y = df['Performance Index']           # target

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# this algorithm is good enough to do predictions upto 98.1%

# %%
y=df.iloc[:,-1] # last column
y
# Out:
# 0       91
# 1       65
# 2       45
# 3       36
# 4       66
#         ..
# 9995    23
# 9996    58
# 9997    74
# 9998    95
# 9999    64
# Name: Performance Index, Length: 10000, dtype: int64

# %%
# train test split
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,train_size=0.7,random_state=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-10-2942423421.py in <cell line: 0>()
# ----> 1 xtrain,xtest,ytrain,ytest=train_test_split(x,y,train_size=0.7,random_state=0)
#
# NameError: name 'y' is not defined

# %%
xtrain
# Out:
# 7681    60
# 9031    43
# 3691    74
# 202     52
# 5625    57
#         ..
# 9225    64
# 4859    78
# 3264    76
# 9845    44
# 2732    83
# Name: Previous Scores, Length: 7000, dtype: int64

# %%
xtrain.ndim
# Out:
# 1

# %%
xtrain.shape
# Out:
# (7000, 1)

# %%
xtrain=xtrain.values.reshape(-1,1) # row unknown
ytrain=ytrain.values.reshape(-1,1)
xtest=xtest.values.reshape(-1,1)
ytest=ytest.values.reshape(-1,1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-11-1296932641.py in <cell line: 0>()
# ----> 1 xtrain=xtrain.values.reshape(-1,1) # row unknown
#       2 ytrain=ytrain.values.reshape(-1,1)
#       3 xtest=xtest.values.reshape(-1,1)
#       4 ytest=ytest.values.reshape(-1,1)
#
# NameError: name 'xtrain' is not defined

# %%
xtrain.shape
# Out:
# (7000, 1)

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('Salary_dataset.csv')
df
# Out:
#     YearsExperience  Salary
# 0               1.2   39344
# 1               1.4   46206
# 2               1.6   37732
# 3               2.1   43526
# 4               2.3   39892
# 5               3.0   56643
# 6               3.1   60151
# 7               3.3   54446
# 8               3.3   64446
# 9               3.8   57190
# 10              4.0   63219
# 11              4.1   55795
# 12              4.1   56958
# 13              4.2   57082
# 14              4.6   61112
# 15              5.0   67939
# 16              5.2   66030
# 17              5.4   83089
# 18              6.0   81364
# 19              6.1   93941
# 20              6.9   91739
# 21              7.2   98274
# 22              8.0  101303
# 23              8.3  113813
# 24              8.8  109432
# 25              9.1  105583
# 26              9.6  116970
# 27              9.7  112636
# 28             10.4  122392
# 29             10.6  121873

# %%
dfr1 = pd.DataFrame(df)

# %%
X = dfr1[['YearsExperience']]  # 2D array
y = dfr1['Salary']             # 1D array

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.7, random_state=0)

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
plt.scatter(X, y, color='blue')
plt.plot(X_test, y_pred, color='green')
plt.title('Simple Linear Regression: Salary vs. Experience')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.legend()
plt.show()
# Out:
# /tmp/ipython-input-56-207421462.py:6: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
